# %%
import model

# %%
data_path = "H-1B_2017.csv"

# %%
raw_df = model.create_df(data_path)
df = model.clean_data(raw_df, False)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (14,15,16,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /home/ji/Downloads/create_features_DF.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['CASE_STATUS'] = (df['CASE_STATUS'] == 'DENIED').astype(int)

# %%
df.head()
# Out:
#             CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 194  I-200-09209-039181            0     09/27/2016    10/03/2016       H-1B
# 195  I-200-16266-171133            0     09/27/2016    10/03/2016       H-1B
# 196  I-200-16266-208642            0     09/27/2016    10/03/2016       H-1B
# 197  I-200-16263-193057            0     09/27/2016    10/03/2016       H-1B
# 198  I-200-16263-433294            0     09/27/2016    10/03/2016       H-1B
#
#     EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 194            10/01/2016          09/20/2019
# 195            09/27/2016          09/21/2019
# 196            03/27/2017          03/26/2020
# 197            03/15/2017          03/12/2020
# 198            11/07/2016          08/31/2017
#
#                             EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 194           CLOUDWICK TECHNOLOGIES INC.                   NaN
# 195     TATA CONSULTANCY SERVICES LIMITED                   NaN
# 196       HEALTH MANAGEMENT SYSTEMS, INC.                   NaN
# 197  BLACKROCK INVESTMENT MANAGEMENT, LLC                   NaN
# 198    UNIVERSITY OF CALIFORNIA, BERKELEY                   NaN
#
#                   EMPLOYER_ADDRESS        ...         H1B_DEPENDENT  \
# 194          39899 BALENTINE DRIVE        ...                     1
# 195       9201 CORPORATE BOULEVARD        ...                     1
# 196          5615 HIGH POINT DRIVE        ...                     0
# 197            40 EAST 52ND STREET        ...                     0
# 198  BERKELEY INTERNATIONAL OFFICE        ...                     0
#
#     WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 194                0           Y               Y                        NaN
# 195                0           Y               M                        NaN
# 196                0           M               M                        NaN
# 197                0           M               Y                        NaN
# 198                0           M               M                        NaN
#
#      WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 194  MOUNTAIN VIEW     SANTA CLARA             CA                94040
# 195         HUDSON          SUMMIT             OH                44236
# 196         IRVING          DALLAS             TX                75038
# 197  SAN FRANCISCO   SAN FRANCISCO             CA                94105
# 198       BERKELEY         ALAMEDA             CA                94720
#
#     ORIGINAL_CERT_DATE
# 194                NaN
# 195                NaN
# 196                NaN
# 197                NaN
# 198                NaN
#
# [5 rows x 52 columns]

# %%
y = df.CASE_STATUS.values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.30, random_state=67, stratify=y)

# %%
X_t = model.create_features_df(X_train)
# Out:
# /home/ji/Downloads/create_features_DF.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['per_employer']=df.groupby('EMPLOYER_NAME')['EMPLOYER_NAME'].transform('count')
# /home/ji/Downloads/create_features_DF.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['per_employer_deny']=df.groupby('EMPLOYER_NAME')['CASE_STATUS'].transform('sum')
# /home/ji/Downloads/create_features_DF.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['EMPLOYER_RATE']=df['per_employer_deny']/df['per_employer']
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/ji/Downloads/create_features_DF.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['per_soc']=df.groupby('SOC_NAME')['SOC_NAME'].transform('count')
# /home/ji/Downloads/create_features_DF.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['per_soc_deny']=df.groupby('SOC_NAME')['CASE_STATUS'].transform('sum')
# /home/ji/Downloads/create_features_DF.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['SOC_RATE']=df['per_soc_deny']/df['per_soc']

# %%
X_t.head()
# Out:
#         CASE_STATUS  FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  \
# 458202            0                   1              1                 0
# 210107            0                   1              0                 0
# 19604             0                   1              1                 0
# 442735            0                   0              1                 0
# 577271            0                   1              0                 0
#
#                                EMPLOYER_NAME  EMPLOYER_RATE  \
# 458202                       INFO LABS, INC.       0.000000
# 210107                           BOCOUP, LLC       0.034285
# 19604      TATA CONSULTANCY SERVICES LIMITED       0.002458
# 442735  CONCEPTS INFORMATION TECHNOLOGY, INC       0.000000
# 577271               DELOITTE CONSULTING LLP       0.021560
#
#                                          SOC_NAME  SOC_RATE  STATE_AK  \
# 458202                  COMPUTER SYSTEMS ANALYSTS  0.009345         0
# 210107                          GRAPHIC DESIGNERS  0.031153         0
# 19604                        COMPUTER PROGRAMMERS  0.008761         0
# 442735                  COMPUTER SYSTEMS ANALYSTS  0.009345         0
# 577271  COMPUTER AND INFORMATION SYSTEMS MANAGERS  0.014541         0
#
#         STATE_AL   ...     STATE_WI  STATE_WV  STATE_WY  STATE_nan  AGENT_N  \
# 458202         0   ...            0         0         0          0        0
# 210107         0   ...            0         0         0          0        0
# 19604          0   ...            0         0         0          0        0
# 442735         0   ...            0         0         0          0        0
# 577271         0   ...            0         0         0          0        0
#
#         AGENT_Y  SUPPORT_N  SUPPORT_Y  LABOR_N  LABOR_Y
# 458202        1          0          1        0        0
# 210107        1          0          0        0        1
# 19604         1          0          1        0        0
# 442735        1          1          0        0        1
# 577271        0          0          0        0        0
#
# [5 rows x 71 columns]

# %%
df_save_em=X_t[['EMPLOYER_NAME','EMPLOYER_RATE']]

# %%
df_save_so=X_t[['SOC_NAME','SOC_RATE']]

# %%
import pandas as pd
def create_features_test(df):
    
    '''
    dummy-ize variables: ???
    input: dataframe
    returns: features dataframe for use in prediction model
    
    '''

    ''' Columns to keep '''
    

    columns_to_keep_03=['CASE_STATUS', 'AGENT_REPRESENTING_EMPLOYER', 'FULL_TIME_POSITION', 'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'LABOR_CON_AGREE', 'WORKSITE_STATE', 'EMPLOYER_NAME', 'SOC_NAME']
    df=df[columns_to_keep_03]
    
    
    
    df_dum_ST = pd.get_dummies(df.WORKSITE_STATE,dummy_na=True)
    df_dum_ST.apply(lambda x: x.value_counts())
    df_dum_ST.columns = map(lambda x: 'STATE_' + str(x), df_dum_ST.columns)

    df_dum_AGENT = pd.get_dummies(df.AGENT_REPRESENTING_EMPLOYER)
    df_dum_AGENT.apply(lambda x: x.value_counts())
    df_dum_AGENT.columns = map(lambda x: 'AGENT_' + str(x), df_dum_AGENT.columns)
    
    df_dum_SUPPORT = pd.get_dummies(df.SUPPORT_H1B)
    df_dum_SUPPORT.apply(lambda x: x.value_counts())
    df_dum_SUPPORT.columns = map(lambda x: 'SUPPORT_' + str(x), df_dum_SUPPORT.columns)
    
    df_dum_LABOR = pd.get_dummies(df.LABOR_CON_AGREE)
    df_dum_LABOR.apply(lambda x: x.value_counts())
    df_dum_LABOR.columns = map(lambda x: 'LABOR_' + str(x), df_dum_LABOR.columns)
    
    df_for_model = pd.concat([df, df_dum_ST, df_dum_AGENT, df_dum_SUPPORT, df_dum_LABOR], axis=1)

    df_for_model.drop(['STATE_CA','WORKSITE_STATE','AGENT_REPRESENTING_EMPLOYER',
                       'SUPPORT_H1B','LABOR_CON_AGREE','AGENT_M','SUPPORT_M','LABOR_M'], inplace=True, axis=1, errors='ignore')
    
    return df_for_model

# %%
X_test_1=create_features_test(X_test)

# %%
X_test_1.head()
# Out:
#         CASE_STATUS  FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  \
# 222268            0                   1              0                 0
# 422385            0                   1              0                 0
# 564464            0                   1              1                 0
# 6090              0                   1              0                 0
# 403535            0                   1              1                 0
#
#                             EMPLOYER_NAME  \
# 222268              BAIG DENTAL GROUP, PC
# 422385                       NETAPP, INC.
# 564464  TATA CONSULTANCY SERVICES LIMITED
# 6090                 TRW AUTOMOTIVE, INC.
# 403535        QUALCOMM TECHNOLOGIES, INC.
#
#                                            SOC_NAME  STATE_AK  STATE_AL  \
# 222268                            DENTISTS, GENERAL         0         0
# 422385        SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE         0         0
# 564464  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS         0         0
# 6090                           ELECTRICAL ENGINEERS         0         0
# 403535       ELECTRONICS ENGINEERS, EXCEPT COMPUTER         0         0
#
#         STATE_AR  STATE_AZ   ...     STATE_WI  STATE_WV  STATE_WY  STATE_nan  \
# 222268         0         0   ...            0         0         0          0
# 422385         0         0   ...            0         0         0          0
# 564464         0         0   ...            0         0         0          0
# 6090           0         0   ...            0         0         0          0
# 403535         0         0   ...            0         0         0          0
#
#         AGENT_N  AGENT_Y  SUPPORT_N  SUPPORT_Y  LABOR_N  LABOR_Y
# 222268        0        1          0          0        0        1
# 422385        0        1          0          0        0        0
# 564464        0        0          0          1        0        0
# 6090          0        1          0          0        0        0
# 403535        0        1          0          1        0        0
#
# [5 rows x 67 columns]

# %%
df_save_em.count()
# Out:
# EMPLOYER_NAME    378743
# EMPLOYER_RATE    378771
# dtype: int64

# %%
group=dict(zip(df_save_em.EMPLOYER_NAME,df_save_em.EMPLOYER_RATE))

# %%
len(group)
# Out:
# 52909

# %%
X_test_1['EMPLOYER_RATE'] = X_test_1['EMPLOYER_NAME'].map(group, na_action=None)

# %%
X_test_1.head()
# Out:
#         CASE_STATUS  FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  \
# 222268            0                   1              0                 0
# 422385            0                   1              0                 0
# 564464            0                   1              1                 0
# 6090              0                   1              0                 0
# 403535            0                   1              1                 0
#
#                             EMPLOYER_NAME  \
# 222268              BAIG DENTAL GROUP, PC
# 422385                       NETAPP, INC.
# 564464  TATA CONSULTANCY SERVICES LIMITED
# 6090                 TRW AUTOMOTIVE, INC.
# 403535        QUALCOMM TECHNOLOGIES, INC.
#
#                                            SOC_NAME  STATE_AK  STATE_AL  \
# 222268                            DENTISTS, GENERAL         0         0
# 422385        SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE         0         0
# 564464  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS         0         0
# 6090                           ELECTRICAL ENGINEERS         0         0
# 403535       ELECTRONICS ENGINEERS, EXCEPT COMPUTER         0         0
#
#         STATE_AR  STATE_AZ      ...        STATE_WV  STATE_WY  STATE_nan  \
# 222268         0         0      ...               0         0          0
# 422385         0         0      ...               0         0          0
# 564464         0         0      ...               0         0          0
# 6090           0         0      ...               0         0          0
# 403535         0         0      ...               0         0          0
#
#         AGENT_N  AGENT_Y  SUPPORT_N  SUPPORT_Y  LABOR_N  LABOR_Y  \
# 222268        0        1          0          0        0        1
# 422385        0        1          0          0        0        0
# 564464        0        0          0          1        0        0
# 6090          0        1          0          0        0        0
# 403535        0        1          0          1        0        0
#
#         EMPLOYER_RATE
# 222268       0.034285
# 422385       0.017442
# 564464       0.002458
# 6090         0.000000
# 403535       0.025090
#
# [5 rows x 68 columns]

# %%
X_test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162331 entries, 222268 to 73902
# Data columns (total 68 columns):
# CASE_STATUS           162331 non-null int64
# FULL_TIME_POSITION    162331 non-null int64
# H1B_DEPENDENT         162331 non-null int64
# WILLFUL_VIOLATOR      162331 non-null int64
# EMPLOYER_NAME         162331 non-null object
# SOC_NAME              162331 non-null object
# STATE_AK              162331 non-null uint8
# STATE_AL              162331 non-null uint8
# STATE_AR              162331 non-null uint8
# STATE_AZ              162331 non-null uint8
# STATE_CO              162331 non-null uint8
# STATE_CT              162331 non-null uint8
# STATE_DC              162331 non-null uint8
# STATE_DE              162331 non-null uint8
# STATE_FL              162331 non-null uint8
# STATE_GA              162331 non-null uint8
# STATE_GU              162331 non-null uint8
# STATE_HI              162331 non-null uint8
# STATE_IA              162331 non-null uint8
# STATE_ID              162331 non-null uint8
# STATE_IL              162331 non-null uint8
# STATE_IN              162331 non-null uint8
# STATE_KS              162331 non-null uint8
# STATE_KY              162331 non-null uint8
# STATE_LA              162331 non-null uint8
# STATE_MA              162331 non-null uint8
# STATE_MD              162331 non-null uint8
# STATE_ME              162331 non-null uint8
# STATE_MI              162331 non-null uint8
# STATE_MN              162331 non-null uint8
# STATE_MO              162331 non-null uint8
# STATE_MP              162331 non-null uint8
# STATE_MS              162331 non-null uint8
# STATE_MT              162331 non-null uint8
# STATE_NC              162331 non-null uint8
# STATE_ND              162331 non-null uint8
# STATE_NE              162331 non-null uint8
# STATE_NH              162331 non-null uint8
# STATE_NJ              162331 non-null uint8
# STATE_NM              162331 non-null uint8
# STATE_NV              162331 non-null uint8
# STATE_NY              162331 non-null uint8
# STATE_OH              162331 non-null uint8
# STATE_OK              162331 non-null uint8
# STATE_OR              162331 non-null uint8
# STATE_PA              162331 non-null uint8
# STATE_PR              162331 non-null uint8
# STATE_RI              162331 non-null uint8
# STATE_SC              162331 non-null uint8
# STATE_SD              162331 non-null uint8
# STATE_TN              162331 non-null uint8
# STATE_TX              162331 non-null uint8
# STATE_UT              162331 non-null uint8
# STATE_VA              162331 non-null uint8
# STATE_VI              162331 non-null uint8
# STATE_VT              162331 non-null uint8
# STATE_WA              162331 non-null uint8
# STATE_WI              162331 non-null uint8
# STATE_WV              162331 non-null uint8
# STATE_WY              162331 non-null uint8
# STATE_nan             162331 non-null uint8
# AGENT_N               162331 non-null uint8
# AGENT_Y               162331 non-null uint8
# SUPPORT_N             162331 non-null uint8
# SUPPORT_Y             162331 non-null uint8
# LABOR_N               162331 non-null uint8
# LABOR_Y               162331 non-null uint8
# EMPLOYER_RATE         162331 non-null float64
# dtypes: float64(1), int64(4), object(2), uint8(61)
# memory usage: 19.4+ MB

# %%
X_test_1.fillna(y_train.mean(), inplace=True)

# %%
y_train.mean()
# Out:
# 0.013826296099754205

# %%
df_save_so.count()
# Out:
# SOC_NAME    378771
# SOC_RATE    378771
# dtype: int64

# %%
group=dict(zip(df_save_so.SOC_NAME,df_save_so.SOC_RATE))

# %%
len(group)
# Out:
# 737

# %%
X_test_1['SOC_RATE'] = X_test_1['SOC_NAME'].map(group, na_action=None)

# %%
X_test_1.head()
# Out:
#         CASE_STATUS  FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  \
# 222268            0                   1              0                 0
# 422385            0                   1              0                 0
# 564464            0                   1              1                 0
# 6090              0                   1              0                 0
# 403535            0                   1              1                 0
#
#                             EMPLOYER_NAME  \
# 222268              BAIG DENTAL GROUP, PC
# 422385                       NETAPP, INC.
# 564464  TATA CONSULTANCY SERVICES LIMITED
# 6090                 TRW AUTOMOTIVE, INC.
# 403535        QUALCOMM TECHNOLOGIES, INC.
#
#                                            SOC_NAME  STATE_AK  STATE_AL  \
# 222268                            DENTISTS, GENERAL         0         0
# 422385        SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE         0         0
# 564464  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS         0         0
# 6090                           ELECTRICAL ENGINEERS         0         0
# 403535       ELECTRONICS ENGINEERS, EXCEPT COMPUTER         0         0
#
#         STATE_AR  STATE_AZ    ...     STATE_WY  STATE_nan  AGENT_N  AGENT_Y  \
# 222268         0         0    ...            0          0        0        1
# 422385         0         0    ...            0          0        0        1
# 564464         0         0    ...            0          0        0        0
# 6090           0         0    ...            0          0        0        1
# 403535         0         0    ...            0          0        0        1
#
#         SUPPORT_N  SUPPORT_Y  LABOR_N  LABOR_Y  EMPLOYER_RATE  SOC_RATE
# 222268          0          0        0        1       0.034285  0.021592
# 422385          0          0        0        0       0.017442  0.013827
# 564464          0          1        0        0       0.002458  0.009920
# 6090            0          0        0        0       0.000000  0.020307
# 403535          0          1        0        0       0.025090  0.015510
#
# [5 rows x 69 columns]

# %%
X_test_1.columns
# Out:
# Index(['CASE_STATUS', 'FULL_TIME_POSITION', 'H1B_DEPENDENT',
#        'WILLFUL_VIOLATOR', 'EMPLOYER_NAME', 'SOC_NAME', 'STATE_AK', 'STATE_AL',
#        'STATE_AR', 'STATE_AZ', 'STATE_CO', 'STATE_CT', 'STATE_DC', 'STATE_DE',
#        'STATE_FL', 'STATE_GA', 'STATE_GU', 'STATE_HI', 'STATE_IA', 'STATE_ID',
#        'STATE_IL', 'STATE_IN', 'STATE_KS', 'STATE_KY', 'STATE_LA', 'STATE_MA',
#        'STATE_MD', 'STATE_ME', 'STATE_MI', 'STATE_MN', 'STATE_MO', 'STATE_MP',
#        'STATE_MS', 'STATE_MT', 'STATE_NC', 'STATE_ND', 'STATE_NE', 'STATE_NH',
#        'STATE_NJ', 'STATE_NM', 'STATE_NV', 'STATE_NY', 'STATE_OH', 'STATE_OK',
#        'STATE_OR', 'STATE_PA', 'STATE_PR', 'STATE_RI', 'STATE_SC', 'STATE_SD',
#        'STATE_TN', 'STATE_TX', 'STATE_UT', 'STATE_VA', 'STATE_VI', 'STATE_VT',
#        'STATE_WA', 'STATE_WI', 'STATE_WV', 'STATE_WY', 'STATE_nan', 'AGENT_N',
#        'AGENT_Y', 'SUPPORT_N', 'SUPPORT_Y', 'LABOR_N', 'LABOR_Y',
#        'EMPLOYER_RATE', 'SOC_RATE'],
#       dtype='object')

# %%
set(X_t.columns)-set(X_test_1.columns)
# Out:
# {'STATE_FM', 'STATE_PW'}

# %%
missing_cols = set(X_t.columns)-set(X_test_1.columns)
# Add a missing column in test set with default value equal to 0
for c in missing_cols:
    X_test_1[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test_1 = X_test_1[X_t.columns]

# %%
X_test_1.drop(['EMPLOYER_NAME','SOC_NAME','CASE_STATUS'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-ad61be0e640b> in <module>()
# ----> 1 X_test_1.drop(['EMPLOYER_NAME','SOC_NAME','CASE_STATUS'], inplace=True, axis=1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['EMPLOYER_NAME' 'SOC_NAME'] not contained in axis"

# %%
X_test_1.drop(['CASE_STATUS'], inplace=True, axis=1)

# %%
X_t.drop(['EMPLOYER_NAME','SOC_NAME', 'CASE_STATUS'], inplace=True, axis=1)

# %%
X_t.drop(['CASE_STATUS'], inplace=True, axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_t, y_train)

# %%
X_test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162331 entries, 222268 to 73902
# Data columns (total 69 columns):
# CASE_STATUS           162331 non-null int64
# FULL_TIME_POSITION    162331 non-null int64
# H1B_DEPENDENT         162331 non-null int64
# WILLFUL_VIOLATOR      162331 non-null int64
# EMPLOYER_RATE         162331 non-null float64
# SOC_RATE              162264 non-null float64
# STATE_AK              162331 non-null uint8
# STATE_AL              162331 non-null uint8
# STATE_AR              162331 non-null uint8
# STATE_AZ              162331 non-null uint8
# STATE_CO              162331 non-null uint8
# STATE_CT              162331 non-null uint8
# STATE_DC              162331 non-null uint8
# STATE_DE              162331 non-null uint8
# STATE_FL              162331 non-null uint8
# STATE_FM              162331 non-null int64
# STATE_GA              162331 non-null uint8
# STATE_GU              162331 non-null uint8
# STATE_HI              162331 non-null uint8
# STATE_IA              162331 non-null uint8
# STATE_ID              162331 non-null uint8
# STATE_IL              162331 non-null uint8
# STATE_IN              162331 non-null uint8
# STATE_KS              162331 non-null uint8
# STATE_KY              162331 non-null uint8
# STATE_LA              162331 non-null uint8
# STATE_MA              162331 non-null uint8
# STATE_MD              162331 non-null uint8
# STATE_ME              162331 non-null uint8
# STATE_MI              162331 non-null uint8
# STATE_MN              162331 non-null uint8
# STATE_MO              162331 non-null uint8
# STATE_MP              162331 non-null uint8
# STATE_MS              162331 non-null uint8
# STATE_MT              162331 non-null uint8
# STATE_NC              162331 non-null uint8
# STATE_ND              162331 non-null uint8
# STATE_NE              162331 non-null uint8
# STATE_NH              162331 non-null uint8
# STATE_NJ              162331 non-null uint8
# STATE_NM              162331 non-null uint8
# STATE_NV              162331 non-null uint8
# STATE_NY              162331 non-null uint8
# STATE_OH              162331 non-null uint8
# STATE_OK              162331 non-null uint8
# STATE_OR              162331 non-null uint8
# STATE_PA              162331 non-null uint8
# STATE_PR              162331 non-null uint8
# STATE_PW              162331 non-null int64
# STATE_RI              162331 non-null uint8
# STATE_SC              162331 non-null uint8
# STATE_SD              162331 non-null uint8
# STATE_TN              162331 non-null uint8
# STATE_TX              162331 non-null uint8
# STATE_UT              162331 non-null uint8
# STATE_VA              162331 non-null uint8
# STATE_VI              162331 non-null uint8
# STATE_VT              162331 non-null uint8
# STATE_WA              162331 non-null uint8
# STATE_WI              162331 non-null uint8
# STATE_WV              162331 non-null uint8
# STATE_WY              162331 non-null uint8
# STATE_nan             162331 non-null uint8
# AGENT_N               162331 non-null uint8
# AGENT_Y               162331 non-null uint8
# SUPPORT_N             162331 non-null uint8
# SUPPORT_Y             162331 non-null uint8
# LABOR_N               162331 non-null uint8
# LABOR_Y               162331 non-null uint8
# dtypes: float64(2), int64(6), uint8(61)
# memory usage: 20.6 MB

# %%
X_test_1.fillna(y_train.mean(), inplace=True)

# %%
rfc.score(X_test_1, y_test)
# Out:
# 1.0

# %%
import sklearn.metrics as skm
import pandas as pd
pd.crosstab(y_test, rfc.predict(X_test_1))
# Out:
# col_0       0     1
# row_0
# 0      160087     0
# 1           0  2244

# %%
skm.roc_auc_score(y_test,rfc.predict_proba(X_test_1)[:,1])
# Out:
# 1.0
