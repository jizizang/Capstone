# %%
import pandas as pd

# %%
df_2017_5row=pd.read_csv('H-1B_2017.csv', nrows=5)

# %%
#check headers
df_2017_5row.T
# Out:
#                                                       0  \
# CASE_NUMBER                          I-200-16055-173457
# CASE_STATUS                         CERTIFIED-WITHDRAWN
# CASE_SUBMITTED                               02/24/2016
# DECISION_DATE                                10/01/2016
# VISA_CLASS                                         H-1B
# EMPLOYMENT_START_DATE                        08/10/2016
# EMPLOYMENT_END_DATE                          08/10/2019
# EMPLOYER_NAME                    DISCOVER PRODUCTS INC.
# EMPLOYER_BUSINESS_DBA                               NaN
# EMPLOYER_ADDRESS                    2500 LAKE COOK ROAD
# EMPLOYER_CITY                                RIVERWOODS
# EMPLOYER_STATE                                       IL
# EMPLOYER_POSTAL_CODE                              60015
# EMPLOYER_COUNTRY               UNITED STATES OF AMERICA
# EMPLOYER_PROVINCE                                   NaN
# EMPLOYER_PHONE                               2244050900
# ...

# %%
df_2017=pd.read_csv('H-1B_2017.csv')
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14,15,16,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#only keep CERTIFIED and DENIED
df_2017.CASE_STATUS.value_counts()
# Out:
# CERTIFIED              545694
# CERTIFIED-WITHDRAWN     49704
# WITHDRAWN               20772
# DENIED                   8480
# Name: CASE_STATUS, dtype: int64

# %%
# can remove E-3 Australian, H-1B1 Singapore, H-1B1 Chile
df_2017.VISA_CLASS.value_counts()
# Out:
# H-1B               610304
# E-3 Australian      12157
# H-1B1 Singapore      1254
# H-1B1 Chile           935
# Name: VISA_CLASS, dtype: int64

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624650 entries, 0 to 624649
# Data columns (total 52 columns):
# CASE_NUMBER                    624650 non-null object
# CASE_STATUS                    624650 non-null object
# CASE_SUBMITTED                 624650 non-null object
# DECISION_DATE                  624650 non-null object
# VISA_CLASS                     624650 non-null object
# EMPLOYMENT_START_DATE          624621 non-null object
# EMPLOYMENT_END_DATE            624620 non-null object
# EMPLOYER_NAME                  624594 non-null object
# EMPLOYER_BUSINESS_DBA          43270 non-null object
# EMPLOYER_ADDRESS               624643 non-null object
# EMPLOYER_CITY                  624635 non-null object
# EMPLOYER_STATE                 624632 non-null object
# EMPLOYER_POSTAL_CODE           624632 non-null object
# EMPLOYER_COUNTRY               528143 non-null object
# EMPLOYER_PROVINCE              6116 non-null object
# ...

# %%
df_2017.head()
# Out:
#           CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16055-173457  CERTIFIED-WITHDRAWN     02/24/2016    10/01/2016
# 1  I-200-16064-557834  CERTIFIED-WITHDRAWN     03/04/2016    10/01/2016
# 2  I-200-16063-996093  CERTIFIED-WITHDRAWN     03/10/2016    10/01/2016
# 3  I-200-16272-196340            WITHDRAWN     09/28/2016    10/01/2016
# 4  I-200-15053-636744  CERTIFIED-WITHDRAWN     02/22/2015    10/02/2016
#
#   VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0       H-1B            08/10/2016          08/10/2019
# 1       H-1B            08/16/2016          08/16/2019
# 2       H-1B            09/09/2016          09/09/2019
# 3       H-1B            01/26/2017          01/25/2020
# 4       H-1B            03/01/2015          03/01/2018
#
#                EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0     DISCOVER PRODUCTS INC.                   NaN
# 1           DFS SERVICES LLC                   NaN
# ...

# %%
df_2017.tail()
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 624645  I-200-16188-449352  CERTIFIED-WITHDRAWN     07/06/2016    09/30/2017
# 624646  I-200-16309-239165            CERTIFIED     11/04/2016    11/10/2016
# 624647  I-200-16363-692687            CERTIFIED     12/28/2016    01/04/2017
# 624648  I-200-17055-511599            CERTIFIED     02/24/2017    03/02/2017
# 624649  I-200-17068-828736            CERTIFIED     03/09/2017    03/15/2017
#
#        VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 624645       H-1B            07/06/2016          07/05/2019
# 624646       H-1B            12/01/2016          11/30/2017
# 624647       H-1B            02/01/2017          01/31/2018
# 624648       H-1B            06/01/2017          05/31/2018
# 624649       H-1B            09/08/2017          09/08/2020
#
#                                 EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 624645                        FAST SWITCH LTD                   NaN
# ...

# %%
pd.to_datetime(df_2017_5row.CASE_SUBMITTED)
# Out:
# 0   2016-02-24
# 1   2016-03-04
# 2   2016-03-10
# 3   2016-09-28
# 4   2015-02-22
# Name: CASE_SUBMITTED, dtype: datetime64[ns]

# %%
df_2017_5row
# Out:
#           CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16055-173457  CERTIFIED-WITHDRAWN     02/24/2016    10/01/2016
# 1  I-200-16064-557834  CERTIFIED-WITHDRAWN     03/04/2016    10/01/2016
# 2  I-200-16063-996093  CERTIFIED-WITHDRAWN     03/10/2016    10/01/2016
# 3  I-200-16272-196340            WITHDRAWN     09/28/2016    10/01/2016
# 4  I-200-15053-636744  CERTIFIED-WITHDRAWN     02/22/2015    10/02/2016
#
#   VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0       H-1B            08/10/2016          08/10/2019
# 1       H-1B            08/16/2016          08/16/2019
# 2       H-1B            09/09/2016          09/09/2019
# 3       H-1B            01/26/2017          01/25/2020
# 4       H-1B            03/01/2015          03/01/2018
#
#                EMPLOYER_NAME  EMPLOYER_BUSINESS_DBA  \
# 0     DISCOVER PRODUCTS INC.                    NaN
# 1           DFS SERVICES LLC                    NaN
# ...

# %%
#CASE_SUBMITTED to date time
date=pd.to_datetime(df_2017.CASE_SUBMITTED)

# %%
#DECISION_DATE to date time
d_date=pd.to_datetime(df_2017.DECISION_DATE)

# %%
date.head()
# Out:
# 0   2016-02-24
# 1   2016-03-04
# 2   2016-03-10
# 3   2016-09-28
# 4   2015-02-22
# Name: CASE_SUBMITTED, dtype: datetime64[ns]

# %%
#number of cases submitted in each month
date.groupby(date.dt.month).count().plot(kind="bar").set_ylabel('number of cases submitted')
# Out:
# Text(0,0.5,'number of cases submitted')

# %%
#number of cases DECISION each month
d_date.groupby(d_date.dt.month).count().plot(kind="bar").set_ylabel('number of cases submitted')
# Out:
# Text(0,0.5,'number of cases submitted')

# %%
import numpy as np

# %%
#CASE_SUBMITTED to_datetime
df_2017.CASE_SUBMITTED=pd.to_datetime(df_2017.CASE_SUBMITTED)

# %%
df_2017[df_2017.CASE_SUBMITTED>'2016-12-31'].count()
# Out:
# CASE_NUMBER                    505974
# CASE_STATUS                    505974
# CASE_SUBMITTED                 505974
# DECISION_DATE                  505974
# VISA_CLASS                     505974
# EMPLOYMENT_START_DATE          505949
# EMPLOYMENT_END_DATE            505945
# EMPLOYER_NAME                  505924
# EMPLOYER_BUSINESS_DBA           33922
# EMPLOYER_ADDRESS               505967
# EMPLOYER_CITY                  505964
# EMPLOYER_STATE                 505961
# EMPLOYER_POSTAL_CODE           505956
# EMPLOYER_COUNTRY               415470
# EMPLOYER_PROVINCE                4808
# EMPLOYER_PHONE                 415469
# EMPLOYER_PHONE_EXT              21817
# AGENT_REPRESENTING_EMPLOYER    415472
# AGENT_ATTORNEY_NAME            505974
# AGENT_ATTORNEY_CITY            283870
# AGENT_ATTORNEY_STATE           272107
# JOB_TITLE                      505969
# SOC_CODE                       505972
# SOC_NAME                       505971
# NAICS_CODE                     505967
# ...

# %%
#number of denied for each month case submitted
df_2017[df_2017.CASE_STATUS=='DENIED']['CASE_STATUS'].groupby(df_2017.CASE_SUBMITTED.dt.month).count().plot(kind="bar").set_ylabel('number of cases denied')
# Out:
# Text(0,0.5,'number of cases denied')

# %%
#only keep DENIED and CERTIFIED
df_2017_status=df_2017[ (df_2017.CASE_STATUS=='DENIED') | (df_2017.CASE_STATUS=='CERTIFIED')]

# %%
df_2017_status.CASE_STATUS.value_counts()
# Out:
# CERTIFIED    545694
# DENIED         8480
# Name: CASE_STATUS, dtype: int64

# %%
df_2017_status[df_2017_status.CASE_STATUS=='DENIED'].mean()
# Out:
# TOTAL_WORKERS                     2.276415
# NEW_EMPLOYMENT                    0.898231
# CONTINUED_EMPLOYMENT              0.364858
# CHANGE_PREVIOUS_EMPLOYMENT        0.226769
# NEW_CONCURRENT_EMPLOYMENT         0.019340
# CHANGE_EMPLOYER                   0.282429
# AMENDED_PETITION                  0.340802
# PREVAILING_WAGE               90454.778615
# PW_SOURCE_YEAR                 2015.538753
# WAGE_RATE_OF_PAY_FROM         70367.623448
# WAGE_RATE_OF_PAY_TO           28285.648034
# PUBLIC_DISCLOSURE_LOCATION             NaN
# dtype: float64

# %%
#case submitted in each month
df_2017_status.groupby(df_2017_status.CASE_SUBMITTED.dt.month).CASE_SUBMITTED.agg('count').to_frame('sub_count').reset_index()
# Out:
#     CASE_SUBMITTED  sub_count
# 0                1      35989
# 1                2      73343
# 2                3     190590
# 3                4      30459
# 4                5      30708
# 5                6      31120
# 6                7      25838
# 7                8      31992
# 8                9      26622
# 9               10      25161
# 10              11      25646
# 11              12      26706

# %%
# case denied in each month
df_2017_status[df_2017_status.CASE_STATUS=='DENIED']['CASE_STATUS'].groupby(df_2017_status.CASE_SUBMITTED.dt.month).count()
# Out:
# CASE_SUBMITTED
# 1      630
# 2      969
# 3     2705
# 4      495
# 5      402
# 6      415
# 7      457
# 8      539
# 9      513
# 10     444
# 11     460
# 12     451
# Name: CASE_STATUS, dtype: int64

# %%
df_2017_status['CASE_STATUS'] = (df_2017_status['CASE_STATUS'] == 'DENIED').astype(int)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2017_status['CASE_STATUS'].mean()
# Out:
# 0.015302053145762884

# %%
df_2017_status.tail()
# Out:
#                CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 624620  I-203-17269-466479            1     2017-09-28    09/29/2017
# 624646  I-200-16309-239165            0     2016-11-04    11/10/2016
# 624647  I-200-16363-692687            0     2016-12-28    01/04/2017
# 624648  I-200-17055-511599            0     2017-02-24    03/02/2017
# 624649  I-200-17068-828736            0     2017-03-09    03/15/2017
#
#             VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 624620  E-3 Australian            11/01/2017          11/01/2019
# 624646            H-1B            12/01/2016          11/30/2017
# 624647            H-1B            02/01/2017          01/31/2018
# 624648            H-1B            06/01/2017          05/31/2018
# 624649            H-1B            09/08/2017          09/08/2020
#
#                                 EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 624620         ELLIOTT MANAGEMENT CORPORATION                   NaN
# ...

# %%
# rejection rate each month
df_2017_status.groupby(df_2017_status.CASE_SUBMITTED.dt.month)['CASE_STATUS'].mean()
# Out:
# CASE_SUBMITTED
# 1     0.017505
# 2     0.013212
# 3     0.014193
# 4     0.016251
# 5     0.013091
# 6     0.013335
# 7     0.017687
# 8     0.016848
# 9     0.019270
# 10    0.017646
# 11    0.017937
# 12    0.016888
# Name: CASE_STATUS, dtype: float64

# %%
# can drop VISA_CLASS after this
df_2017_status= df_2017_status[df_2017_status.VISA_CLASS != 'H-1B1 Chile']
#E-3 Australian      12157
#H-1B1 Singapore      1254
#H-1B1 Chile           935

# %%
df_2017_status= df_2017_status[df_2017_status.VISA_CLASS != 'H-1B1 Singapore']

# %%
df_2017_status= df_2017_status[df_2017_status.VISA_CLASS != 'E-3 Australian']

# %%
df_2017_status.VISA_CLASS.value_counts()
# Out:
# H-1B    541102
# Name: VISA_CLASS, dtype: int64

# %%
agg = df_2017_status.groupby('WORKSITE_STATE')['CASE_STATUS'].mean()
agg.plot(kind='bar',figsize=(10,4)).set_ylabel('rejection rate')
df_2017_status.WORKSITE_STATE.value_counts()
# Out:
# CA    101273
# TX     57794
# NY     45317
# NJ     37172
# IL     28496
# WA     22152
# MA     21697
# GA     20061
# FL     19032
# PA     18908
# MI     17577
# VA     15690
# NC     15068
# OH     13767
# MN      9275
# MD      9171
# AZ      8429
# CT      7155
# MO      7036
# TN      6081
# WI      5786
# CO      5632
# IN      5302
# OR      4065
# DC      3567
# DE      3029
# IA      2688
# UT      2609
# SC      2529
# AR      2451
# KS      2423
# KY      2386
# RI      2172
# NE      1872
# LA      1646
# OK      1511
# AL      1504
# NH      1264
# NV      1234
# ID       774
# NM       758
# MS       649
# ME       605
# PR       533
# HI       434
# WV       407
# ND       393
# VT       358
# MP       311
# GU       302
# SD       259
# MT       175
# AK       164
# WY       101
# VI        48
# PW         2
# FM         1
# Name: WORKSITE_STATE, dtype: int64

# %%
agg = df_2017_status.groupby('LABOR_CON_AGREE')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.LABOR_CON_AGREE.value_counts()
# Out:
# Y    205517
# N      9824
# Name: LABOR_CON_AGREE, dtype: int64

# %%
agg = df_2017_status.groupby('SUPPORT_H1B')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.SUPPORT_H1B.value_counts()
# Out:
# Y    208698
# N      6962
# Name: SUPPORT_H1B, dtype: int64

# %%
agg = df_2017_status.groupby('WILLFUL_VIOLATOR')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.WILLFUL_VIOLATOR.value_counts()
# Out:
# N    540765
# Y       335
# Name: WILLFUL_VIOLATOR, dtype: int64

# %%
#??? Employers who hire ‘too many’ H1B workers are labeled H1B Dependent Employers.???
agg = df_2017_status.groupby('H1B_DEPENDENT')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.H1B_DEPENDENT.value_counts()
# Out:
# N    330843
# Y    210257
# Name: H1B_DEPENDENT, dtype: int64

# %%
agg = df_2017_status.groupby('WAGE_UNIT_OF_PAY')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.WAGE_UNIT_OF_PAY.value_counts()
# Out:
# Year         507529
# Hour          32991
# Month           364
# Week            136
# Bi-Weekly        79
# Name: WAGE_UNIT_OF_PAY, dtype: int64

# %%
agg = df_2017_status.groupby('FULL_TIME_POSITION')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.FULL_TIME_POSITION.value_counts()
# Out:
# Y    528971
# N     12129
# Name: FULL_TIME_POSITION, dtype: int64

# %%
agg = df_2017_status.groupby('AMENDED_PETITION')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.AMENDED_PETITION.value_counts()
# Out:
# 0     437388
# 1      89216
# 5       3337
# 15      3211
# 2       2435
# 3       2040
# 9       1504
# 4        735
# 10       722
# 11       255
# 8         89
# 6         87
# 50        38
# 20        16
# 30        12
# 25         7
# 7          6
# 18         2
# 13         1
# 34         1
# Name: AMENDED_PETITION, dtype: int64

# %%
agg = df_2017_status.groupby('CHANGE_EMPLOYER')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
# Out:
# Text(0,0.5,'rejection rate')

# %%
df_2017_status.CHANGE_EMPLOYER.value_counts()
# Out:
# 0      450079
# 1       77150
# 5        4816
# 2        3056
# 3        2131
# 6        1584
# 15        801
# 4         772
# 10        474
# 8         101
# 50         43
# 25         34
# 20         24
# 30         11
# 7          11
# 75          4
# 150         2
# 9           2
# 14          2
# 12          2
# 100         1
# 21          1
# 35          1
# Name: CHANGE_EMPLOYER, dtype: int64

# %%
agg = df_2017_status.groupby('NEW_CONCURRENT_EMPLOYMENT')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.NEW_CONCURRENT_EMPLOYMENT.value_counts()
# Out:
# 0     537531
# 1       2608
# 2        732
# 5        199
# 3         17
# 10         9
# 15         3
# 50         1
# 11         1
# 6          1
# Name: NEW_CONCURRENT_EMPLOYMENT, dtype: int64

# %%
agg = df_2017_status.groupby('CHANGE_PREVIOUS_EMPLOYMENT')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.CHANGE_PREVIOUS_EMPLOYMENT.value_counts()
# Out:
# 0     500481
# 1      32352
# 2       2364
# 5       2338
# 3       1663
# 4        692
# 10       393
# 25       333
# 15       244
# 8         89
# 6         75
# 50        43
# 20        25
# 30         4
# 40         2
# 7          1
# 45         1
# 19         1
# 9          1
# Name: CHANGE_PREVIOUS_EMPLOYMENT, dtype: int64

# %%
agg = df_2017_status.groupby('CONTINUED_EMPLOYMENT')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.CONTINUED_EMPLOYMENT.value_counts()
# Out:
# 0     422200
# 1     104832
# 5       4901
# 3       2891
# 2       2464
# 9       1516
# 4        720
# 10       548
# 15       482
# 25       199
# 8        108
# 50       102
# 6         80
# 30        19
# 20        13
# 14         7
# 12         4
# 22         4
# 7          3
# 28         2
# 40         2
# 55         2
# 17         1
# 18         1
# 35         1
# Name: CONTINUED_EMPLOYMENT, dtype: int64

# %%
agg = df_2017_status.groupby('TOTAL_WORKERS')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.TOTAL_WORKERS.value_counts()
# Out:
# 1      493285
# 15       9355
# 3        6811
# 5        6142
# 2        6110
# 10       5700
# 20       3501
# 30       2400
# 25       2148
# 6        1898
# 4        1166
# 50       1010
# 8         300
# 9         248
# 40        203
# 7         177
# 150       144
# 12        102
# 100       100
# 75         56
# 18         27
# 35         27
# 13         26
# 16         25
# 14         23
# 11         23
# 60         22
# 45          9
# 65          7
# 24          7
# 28          5
# 21          4
# 17          4
# 26          3
# 70          3
# 22          3
# 55          3
# 27          2
# 19          2
# 31          2
# 32          2
# 33          2
# 34          2
# 80          2
# 99          2
# 23          1
# 29          1
# 36          1
# 38          1
# 41          1
# 54          1
# 110         1
# 115         1
# 155         1
# Name: TOTAL_WORKERS, dtype: int64

# %%
agg = df_2017_status.groupby('SOC_CODE')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.SOC_CODE.value_counts()
# Out:
# 15-1132       108372
# 15-1121       100087
# 15-1131        58552
# 15-1199        52232
# 15-1133        16269
# 13-1111        11814
# 13-2011        10422
# 15-1142         9743
# 17-2141         8630
# 15-2031         8359
# 13-2051         7785
# 15-1141         6872
# 13-1161         6239
# 11-3021         5958
# 17-2072         5737
# 17-2071         5489
# 29-1069         5178
# 15-1134         4882
# 15-2041         4346
# 19-1042         3583
# 17-2199         3000
# 17-2112         2976
# 17-2051         2946
# 19-1029         2669
# 29-1123         2658
# 19-1021         2305
# 41-9031         2049
# 11-2021         2038
# 13-2099         2008
# 19-2031         1937
#                ...
# 39-5012            1
# 19-3022.00         1
# 15.1199.02         1
# 25-4012.00         1
# 27-3021.00         1
# 49-9061            1
# 13-1161.00         1
# 26-1065            1
# 17-3011.01         1
# 29-2055            1
# 47-2044            1
# 11-9121.01         1
# ...

# %%
agg = df_2017_status.groupby('AGENT_ATTORNEY_STATE')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.AGENT_ATTORNEY_STATE.value_counts()
# Out:
# CA    57899
# NY    44638
# TX    24589
# IL    21716
# MA    21525
# MI    16191
# NJ    14840
# GA    14835
# VA    14775
# DC    10414
# OH     6510
# FL     6456
# MD     6161
# PA     6095
# NC     5774
# CT     3103
# MN     2838
# WA     2006
# CO     1820
# MO     1691
# WI     1535
# AZ     1269
# NE     1057
# TN      979
# SC      801
# OR      714
# UT      657
# IN      535
# LA      452
# OK      414
# ME      347
# AL      339
# KY      317
# IA      273
# GU      258
# ID      252
# KS      198
# NV      182
# NH      176
# RI      167
# AR      163
# NM      124
# HI      119
# MS       80
# PR       64
# VT       55
# DE       43
# MP       33
# SD       24
# ND       16
# MT       16
# AK       12
# WV        3
# WY        3
# VI        2
# Name: AGENT_ATTORNEY_STATE, dtype: int64

# %%
agg = df_2017_status.groupby('AGENT_REPRESENTING_EMPLOYER')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.AGENT_REPRESENTING_EMPLOYER.value_counts()
# Out:
# Y    309938
# N    148486
# Name: AGENT_REPRESENTING_EMPLOYER, dtype: int64

# %%
agg = df_2017_status.groupby('EMPLOYER_COUNTRY')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.EMPLOYER_COUNTRY.value_counts()
# Out:
# UNITED STATES OF AMERICA    458416
# CANADA                           6
# AUSTRALIA                        2
# CHINA                            1
# CAMBODIA                         1
# Name: EMPLOYER_COUNTRY, dtype: int64

# %%
agg = df_2017_status.groupby('EMPLOYER_STATE')['CASE_STATUS'].mean()
agg.plot(kind='bar',figsize=(10,4)).set_ylabel('rejection rate')
df_2017_status.EMPLOYER_STATE.value_counts()
# Out:
# CA    89547
# TX    78530
# NJ    67478
# IL    37098
# NY    35472
# MI    23881
# PA    23031
# MA    20452
# MD    20100
# WA    17736
# FL    16860
# VA    16662
# NC    14989
# GA    14494
# OH     8298
# CT     4839
# MO     4428
# MN     4093
# TN     3952
# AZ     3405
# WI     3069
# CO     2962
# IN     2446
# DE     2216
# KY     1894
# AR     1820
# IA     1777
# DC     1751
# KS     1686
# UT     1610
# NE     1527
# SC     1358
# OR     1249
# LA     1080
# AL     1061
# RI      898
# OK      876
# NH      874
# NV      778
# PR      563
# NM      562
# ID      556
# MS      426
# ME      426
# VT      386
# MP      304
# GU      300
# WV      294
# ND      267
# HI      258
# SD      185
# MT      106
# WY       68
# AK       56
# VI       54
# AS        1
# Name: EMPLOYER_STATE, dtype: int64

# %%
df_2017_status['CASE_STATUS'].mean()
# Out:
# 0.013825489464093645

# %%
df_2017_status[df_2017_status.CASE_SUBMITTED>'2016-12-31'].CASE_STATUS.count()
# Out:
# 462064

# %%
df_2017_status[df_2017_status.CASE_SUBMITTED<='2016-12-31'].CASE_STATUS.count()
# Out:
# 79038

# %%
df_2017_status[df_2017_status.CASE_SUBMITTED>'2016-12-31'].CASE_STATUS.mean()
# Out:
# 0.013690744139340004

# %%
df_2017_status[df_2017_status.CASE_SUBMITTED<='2016-12-31'].CASE_STATUS.mean()
# Out:
# 0.014613224018826388

# %%
df_2017_status.head().T
# Out:
#                                                            194  \
# CASE_NUMBER                                 I-200-09209-039181
# CASE_STATUS                                                  0
# CASE_SUBMITTED                             2016-09-27 00:00:00
# DECISION_DATE                                       10/03/2016
# VISA_CLASS                                                H-1B
# EMPLOYMENT_START_DATE                               10/01/2016
# EMPLOYMENT_END_DATE                                 09/20/2019
# EMPLOYER_NAME                      CLOUDWICK TECHNOLOGIES INC.
# EMPLOYER_BUSINESS_DBA                                      NaN
# EMPLOYER_ADDRESS                         39899 BALENTINE DRIVE
# EMPLOYER_CITY                                           NEWARK
# EMPLOYER_STATE                                              CA
# EMPLOYER_POSTAL_CODE                                     94560
# EMPLOYER_COUNTRY                      UNITED STATES OF AMERICA
# ...

# %%
columns_to_keep=['CASE_STATUS', 'CASE_SUBMITTED', 'EMPLOYER_STATE', 'AGENT_REPRESENTING_EMPLOYER',
       'JOB_TITLE', 'SOC_CODE', 'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS',
       'FULL_TIME_POSITION', 'PREVAILING_WAGE',
       'PW_WAGE_LEVEL', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_UNIT_OF_PAY',
       'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'LABOR_CON_AGREE',
       'WORKSITE_STATE']

# %%
columns_to_discard=['CASE_NUMBER', 'DECISION_DATE', 'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
                    'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS', 'EMPLOYER_CITY', 'EMPLOYER_POSTAL_CODE',
                    'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE', 'EMPLOYER_PHONE_EXT', 'AGENT_ATTORNEY_NAME',
                    'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE', 'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT', 
                    'CHANGE_PREVIOUS_EMPLOYMENT', 'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION','PW_UNIT_OF_PAY', 
                    'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER', 'WAGE_RATE_OF_PAY_TO', 
                    'PUBLIC_DISCLOSURE_LOCATION', 'WORKSITE_CITY', 'WORKSITE_COUNTY', 'WORKSITE_POSTAL_CODE', 'ORIGINAL_CERT_DATE']

# %%
df_2017_status.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE',
#        'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
#        'EMPLOYER_NAME', 'EMPLOYER_BUSINESS_DBA', 'EMPLOYER_ADDRESS',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'AGENT_REPRESENTING_EMPLOYER',
#        'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_STATE',
#        'JOB_TITLE', 'SOC_CODE', 'SOC_NAME', 'NAICS_CODE', 'TOTAL_WORKERS',
#        'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT', 'CHANGE_PREVIOUS_EMPLOYMENT',
#        'NEW_CONCURRENT_EMPLOYMENT', 'CHANGE_EMPLOYER', 'AMENDED_PETITION',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_LEVEL', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
# ...

# %%
agg = df_2017_status.groupby('PW_WAGE_LEVEL')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.PW_WAGE_LEVEL.value_counts()
# Out:
# Level I      190661
# Level II     158218
# Level III     55184
# Level IV      31105
# Name: PW_WAGE_LEVEL, dtype: int64

# %%
df_2017_status.apply(lambda x:len(x.unique()))
# Out:
# CASE_NUMBER                    541102
# CASE_STATUS                         2
# CASE_SUBMITTED                    363
# DECISION_DATE                     252
# VISA_CLASS                          1
# EMPLOYMENT_START_DATE             556
# EMPLOYMENT_END_DATE              1540
# EMPLOYER_NAME                   64114
# EMPLOYER_BUSINESS_DBA            8309
# EMPLOYER_ADDRESS                58080
# EMPLOYER_CITY                    4904
# EMPLOYER_STATE                     57
# EMPLOYER_POSTAL_CODE            10465
# EMPLOYER_COUNTRY                    6
# EMPLOYER_PROVINCE                 281
# EMPLOYER_PHONE                  73024
# EMPLOYER_PHONE_EXT               1328
# AGENT_REPRESENTING_EMPLOYER         3
# AGENT_ATTORNEY_NAME              6184
# AGENT_ATTORNEY_CITY              1014
# AGENT_ATTORNEY_STATE               56
# JOB_TITLE                       81588
# SOC_CODE                          676
# SOC_NAME                          795
# NAICS_CODE                       2630
# ...

# %%
df_2017_status.isnull().sum()[df_2017_status.isnull().sum() > 0]
# Out:
# EMPLOYMENT_START_DATE              21
# EMPLOYMENT_END_DATE                21
# EMPLOYER_NAME                      34
# EMPLOYER_BUSINESS_DBA          504973
# EMPLOYER_ADDRESS                    2
# EMPLOYER_CITY                      10
# EMPLOYER_STATE                     13
# EMPLOYER_POSTAL_CODE               12
# EMPLOYER_COUNTRY                82676
# EMPLOYER_PROVINCE              536215
# EMPLOYER_PHONE                  82676
# EMPLOYER_PHONE_EXT             517338
# AGENT_REPRESENTING_EMPLOYER     82678
# AGENT_ATTORNEY_CITY            231166
# AGENT_ATTORNEY_STATE           245547
# JOB_TITLE                           2
# NAICS_CODE                          3
# FULL_TIME_POSITION                  2
# PREVAILING_WAGE                     1
# PW_UNIT_OF_PAY                     28
# PW_WAGE_LEVEL                  105934
# PW_SOURCE                          28
# PW_SOURCE_YEAR                     28
# PW_SOURCE_OTHER                  4501
# WAGE_RATE_OF_PAY_TO                 1
# ...

# %%
df_2017_status.PUBLIC_DISCLOSURE_LOCATION .value_counts()
# Out:
# Series([], Name: PUBLIC_DISCLOSURE_LOCATION, dtype: int64)

# %%
df_2017_status.WAGE_RATE_OF_PAY_FROM.hist(bins=50, histtype='bar', by=df_2017_status.CASE_STATUS, stacked=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f88e58d9cf8>,
# ...
#       dtype=object)

# %%
df_2017_status.WAGE_RATE_OF_PAY_FROM.hist(bins=50)

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

x = df_2017_status.WAGE_RATE_OF_PAY_FROM[df_2017_status['CASE_STATUS'] == 1]
#y = df_2017_status.WAGE_RATE_OF_PAY_FROM[df_2017_status['CASE_STATUS'] == 0]
bins = np.linspace(0, 500000, 50)

#plt.hist([x, y], bins, label=['x', 'y'])
plt.hist(x, bins, label=['x'])
plt.legend(loc='upper right')
plt.show()
y = df_2017_status.WAGE_RATE_OF_PAY_FROM[df_2017_status['CASE_STATUS'] == 0]
plt.hist(y, bins, label=['y'])
plt.show()

# %%
agg = df_2017_status.groupby('PW_SOURCE')['CASE_STATUS'].mean()
agg.plot(kind='bar',ylim=(0,0.04)).set_ylabel('rejection rate')
df_2017_status.PW_SOURCE.value_counts()
# Out:
# OES      439392
# Other     98339
# CBA        3309
# DBA          22
# SCA          12
# Name: PW_SOURCE, dtype: int64

# %%
VSC=['AL','AK','CT','DE','KY','LA','ME','DC','MD','MA','MS','NH','NJ','NM','NY','OK','PA','PR','RI','SC','TN','VI','VT','VA','WV']

# %%
df_2017_status['VSC']=0

# %%
df_2017_status.ix[df_2017_status.WORKSITE_STATE.isin(VSC), 'VSC'] = 1
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_2017_status.VSC.value_counts()
# Out:
# 0    356781
# 1    184321
# Name: VSC, dtype: int64

# %%
agg = df_2017_status.groupby('VSC')['CASE_STATUS'].mean()
agg.plot(kind='bar').set_ylabel('rejection rate')
df_2017_status.VSC.value_counts()
# Out:
# 0    356781
# 1    184321
# Name: VSC, dtype: int64

# %%
df_2017_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541102 entries, 194 to 624649
# Data columns (total 53 columns):
# CASE_NUMBER                    541102 non-null object
# CASE_STATUS                    541102 non-null int64
# CASE_SUBMITTED                 541102 non-null datetime64[ns]
# DECISION_DATE                  541102 non-null object
# VISA_CLASS                     541102 non-null object
# EMPLOYMENT_START_DATE          541081 non-null object
# EMPLOYMENT_END_DATE            541081 non-null object
# EMPLOYER_NAME                  541068 non-null object
# EMPLOYER_BUSINESS_DBA          36129 non-null object
# EMPLOYER_ADDRESS               541100 non-null object
# EMPLOYER_CITY                  541092 non-null object
# EMPLOYER_STATE                 541089 non-null object
# EMPLOYER_POSTAL_CODE           541090 non-null object
# EMPLOYER_COUNTRY               458426 non-null object
# EMPLOYER_PROVINCE              4887 non-null object
# ...

# %%
#first model
columns_to_keep_00=['CASE_STATUS', 'AGENT_REPRESENTING_EMPLOYER', 'FULL_TIME_POSITION', 'PW_WAGE_LEVEL', 'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'LABOR_CON_AGREE']

# %%
df_00=df_2017_status[columns_to_keep_00]

# %%
df_00.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541102 entries, 194 to 624649
# Data columns (total 8 columns):
# CASE_STATUS                    541102 non-null int64
# AGENT_REPRESENTING_EMPLOYER    458424 non-null object
# FULL_TIME_POSITION             541100 non-null object
# PW_WAGE_LEVEL                  435168 non-null object
# H1B_DEPENDENT                  541100 non-null object
# WILLFUL_VIOLATOR               541100 non-null object
# SUPPORT_H1B                    215660 non-null object
# LABOR_CON_AGREE                215341 non-null object
# dtypes: int64(1), object(7)
# memory usage: 57.2+ MB

# %%
#all category
for i in columns_to_keep_00:
    print(df_00[i].value_counts())
    print(df_00[i].isnull().sum())
    print()
# Out:
# 0    533621
# 1      7481
# Name: CASE_STATUS, dtype: int64
# 0
#
# Y    309938
# N    148486
# Name: AGENT_REPRESENTING_EMPLOYER, dtype: int64
# 82678
#
# Y    528971
# N     12129
# Name: FULL_TIME_POSITION, dtype: int64
# 2
#
# Level I      190661
# Level II     158218
# Level III     55184
# Level IV      31105
# Name: PW_WAGE_LEVEL, dtype: int64
# 105934
#
# N    330843
# Y    210257
# Name: H1B_DEPENDENT, dtype: int64
# 2
#
# N    540765
# Y       335
# Name: WILLFUL_VIOLATOR, dtype: int64
# 2
#
# Y    208698
# N      6962
# Name: SUPPORT_H1B, dtype: int64
# 325442
#
# Y    205517
# N      9824
# Name: LABOR_CON_AGREE, dtype: int64
# 325761

# %%
#fill NAN with mode?
df_00.AGENT_REPRESENTING_EMPLOYER.fillna('Y', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_00.H1B_DEPENDENT.fillna('N', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_00.WILLFUL_VIOLATOR.fillna('N', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_00.SUPPORT_H1B.fillna('Y', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_00.LABOR_CON_AGREE.fillna('Y', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_00.FULL_TIME_POSITION.fillna('Y', inplace=True)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
for i in columns_to_keep_00:
    print(df_00[i].value_counts())
    print(df_00[i].isnull().sum())
    print()
# Out:
# 0    533621
# 1      7481
# Name: CASE_STATUS, dtype: int64
# 0
#
# Y    392616
# N    148486
# Name: AGENT_REPRESENTING_EMPLOYER, dtype: int64
# 0
#
# Y    528973
# N     12129
# Name: FULL_TIME_POSITION, dtype: int64
# 0
#
# Level I      190661
# Level II     158218
# Level III     55184
# Level IV      31105
# Name: PW_WAGE_LEVEL, dtype: int64
# 105934
#
# N    330845
# Y    210257
# Name: H1B_DEPENDENT, dtype: int64
# 0
#
# N    540767
# Y       335
# Name: WILLFUL_VIOLATOR, dtype: int64
# 0
#
# Y    534140
# N      6962
# Name: SUPPORT_H1B, dtype: int64
# 0
#
# Y    531278
# N      9824
# Name: LABOR_CON_AGREE, dtype: int64
# 0

# %%
df_00.head()
# Out:
#      CASE_STATUS AGENT_REPRESENTING_EMPLOYER FULL_TIME_POSITION PW_WAGE_LEVEL  \
# 194            0                           Y                  Y       Level I
# 195            0                           Y                  Y     Level III
# 196            0                           Y                  Y      Level II
# 197            0                           Y                  Y     Level III
# 198            0                           N                  Y      Level II
#
#     H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE
# 194             Y                N           Y               Y
# 195             Y                N           Y               Y
# 196             N                N           Y               Y
# 197             N                N           Y               Y
# 198             N                N           Y               Y

# %%
# Y/N to 1/0
df_00['AGENT_REPRESENTING_EMPLOYER'] = (df_00['AGENT_REPRESENTING_EMPLOYER'] == 'Y').astype(int)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_00['FULL_TIME_POSITION'] = (df_00['FULL_TIME_POSITION'] == 'Y').astype(int)
df_00['H1B_DEPENDENT'] = (df_00['H1B_DEPENDENT'] == 'Y').astype(int)
df_00['WILLFUL_VIOLATOR'] = (df_00['WILLFUL_VIOLATOR'] == 'Y').astype(int)
df_00['SUPPORT_H1B'] = (df_00['SUPPORT_H1B'] == 'Y').astype(int)
df_00['LABOR_CON_AGREE'] = (df_00['LABOR_CON_AGREE'] == 'Y').astype(int)
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_00.columns
# Out:
# Index(['CASE_STATUS', 'AGENT_REPRESENTING_EMPLOYER', 'FULL_TIME_POSITION',
#        'PW_WAGE_LEVEL', 'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B',
#        'LABOR_CON_AGREE'],
#       dtype='object')

# %%
df_00_inp=df_00[['AGENT_REPRESENTING_EMPLOYER', 'FULL_TIME_POSITION', 'H1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B','LABOR_CON_AGREE']]
y=df_00.CASE_STATUS.values

# %%
df_00.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541102 entries, 194 to 624649
# Data columns (total 8 columns):
# CASE_STATUS                    541102 non-null int64
# AGENT_REPRESENTING_EMPLOYER    541102 non-null int64
# FULL_TIME_POSITION             541102 non-null int64
# PW_WAGE_LEVEL                  435168 non-null object
# H1B_DEPENDENT                  541102 non-null int64
# WILLFUL_VIOLATOR               541102 non-null int64
# SUPPORT_H1B                    541102 non-null int64
# LABOR_CON_AGREE                541102 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 57.2+ MB

# %%
y.shape
# Out:
# (541102,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df_00_inp, y, test_size=0.30, random_state=67, stratify=y)

# %%
#first model
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc.score(X_test, y_test)
# Out:
# 0.9861763926791556

# %%
#nice base line
pd.crosstab(y_test, rfc.predict(X_test))
# Out:
# col_0       0
# row_0
# 0      160087
# 1        2244

# %%
#random guess???
import sklearn.metrics as skm
import numpy as np
skm.roc_auc_score(y_test,rfc.predict(X_test))
# Out:
# 0.5

# %%
y_test.sum()
# Out:
# 2244

# %%
df_2017_status.head().T
# Out:
#                                                            194  \
# CASE_NUMBER                                 I-200-09209-039181
# CASE_STATUS                                                  0
# CASE_SUBMITTED                             2016-09-27 00:00:00
# DECISION_DATE                                       10/03/2016
# VISA_CLASS                                                H-1B
# EMPLOYMENT_START_DATE                               10/01/2016
# EMPLOYMENT_END_DATE                                 09/20/2019
# EMPLOYER_NAME                      CLOUDWICK TECHNOLOGIES INC.
# EMPLOYER_BUSINESS_DBA                                      NaN
# EMPLOYER_ADDRESS                         39899 BALENTINE DRIVE
# EMPLOYER_CITY                                           NEWARK
# EMPLOYER_STATE                                              CA
# EMPLOYER_POSTAL_CODE                                     94560
# EMPLOYER_COUNTRY                      UNITED STATES OF AMERICA
# ...

# %%
df_2017_status.groupby('EMPLOYER_NAME')['CASE_STATUS'].mean().nlargest(100)
# Out:
# EMPLOYER_NAME
# 1SHIWUYOU, LLC                                                        1.0
# 212BOX ARCHITECTURE PC                                                1.0
# 3 FUERZAS TECHNOLOGY SOLUTIONS LLC                                    1.0
# 5SUNS INC                                                             1.0
# A&J AGENCY LLC                                                        1.0
# AARC ENVIRONMENTAL, INC                                               1.0
# ACADEMY OF COUTURE ART INC                                            1.0
# ACADEMY OF COUTURE ART, INC.                                          1.0
# ACADIANA PEDIATRIC GASTROENTEROLOGY AND HEPATOLOGY ASSOCIATES, LLC    1.0
# ACCESS THERAPIES, INC.                                                1.0
# ACOMB OSTENDORF & ASSOCIATES, LLC                                     1.0
# ACTNANO INC                                                           1.0
# ...

# %%
#how many application for EMPLOYER
df_2017_status['per_employer']=df_2017_status.groupby('EMPLOYER_NAME')['EMPLOYER_NAME'].transform('count')

# %%
df_2017_status['per_employer'].describe()
# Out:
# count    541068.000000
# mean       2046.453595
# std        4649.681289
# min           1.000000
# 25%          14.000000
# 50%          81.000000
# 75%         866.000000
# max       20539.000000
# Name: per_employer, dtype: float64

# %%
#how many deny for EMPLOYER
df_2017_status['per_employer_deny']=df_2017_status.groupby('EMPLOYER_NAME')['CASE_STATUS'].transform('sum')

# %%
df_2017_status.head()
# Out:
#             CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 194  I-200-09209-039181            0     2016-09-27    10/03/2016       H-1B
# 195  I-200-16266-171133            0     2016-09-27    10/03/2016       H-1B
# 196  I-200-16266-208642            0     2016-09-27    10/03/2016       H-1B
# 197  I-200-16263-193057            0     2016-09-27    10/03/2016       H-1B
# 198  I-200-16263-433294            0     2016-09-27    10/03/2016       H-1B
#
#     EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 194            10/01/2016          09/20/2019
# 195            09/27/2016          09/21/2019
# 196            03/27/2017          03/26/2020
# 197            03/15/2017          03/12/2020
# 198            11/07/2016          08/31/2017
#
#                             EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 194           CLOUDWICK TECHNOLOGIES INC.                   NaN
# 195     TATA CONSULTANCY SERVICES LIMITED                   NaN
# ...

# %%
#denial rate for employer
df_2017_status['employer_rate=']=df_2017_status['per_employer_deny']/df_2017_status['per_employer']

# %%
df_2017_status['employer_rate='].describe()
# Out:
# count    541068.000000
# mean          0.013819
# std           0.063205
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.007435
# max           1.000000
# Name: employer_rate=, dtype: float64

# %%
df_2017_status['employer_rate='].describe()
# Out:
# count    541068.000000
# mean          0.013819
# std           0.063205
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.007435
# max           1.000000
# Name: employer_rate=, dtype: float64

# %%
#use average for employer with application < 5
mask = df_2017_status.per_employer < 5
column_name = 'employer_rate='
df_2017_status.loc[mask, column_name] = df_2017_status.CASE_STATUS.mean()

# %%
df_2017_status.CASE_STATUS.mean()
# Out:
# 0.013825489464093645

# %%
(df_2017_status.per_employer > 4).sum()
# Out:
# 460230

# %%
(df_2017_status.per_employer < 5).sum()
# Out:
# 80838

# %%
#small company high rejeciton
df_2017_status[(df_2017_status.per_employer < 5)].CASE_STATUS.mean()
# Out:
# 0.0364556273039907

# %%
df_2017_status.head(20)
# Out:
#             CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 194  I-200-09209-039181            0     2016-09-27    10/03/2016       H-1B
# 195  I-200-16266-171133            0     2016-09-27    10/03/2016       H-1B
# 196  I-200-16266-208642            0     2016-09-27    10/03/2016       H-1B
# 197  I-200-16263-193057            0     2016-09-27    10/03/2016       H-1B
# 198  I-200-16263-433294            0     2016-09-27    10/03/2016       H-1B
# 199  I-200-16263-134468            0     2016-09-27    10/03/2016       H-1B
# 200  I-200-16095-028210            0     2016-09-27    10/03/2016       H-1B
# 201  I-200-16271-793080            0     2016-09-27    10/03/2016       H-1B
# 202  I-200-16155-597652            0     2016-09-27    10/03/2016       H-1B
# 203  I-200-16189-475335            0     2016-09-27    10/03/2016       H-1B
# 204  I-200-16237-360926            0     2016-09-27    10/03/2016       H-1B
# ...

# %%
#fill nan
df_2017_status['employer_rate='].fillna(df_2017_status.CASE_STATUS.mean(), inplace=True)

# %%
df_00_inp['rate']=df_2017_status['employer_rate=']
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_00_inp
# Out:
#         AGENT_REPRESENTING_EMPLOYER  FULL_TIME_POSITION  H1B_DEPENDENT  \
# 194                               1                   1              1
# 195                               1                   1              1
# 196                               1                   1              0
# 197                               1                   1              0
# 198                               0                   1              0
# 199                               1                   1              1
# 200                               1                   1              0
# 201                               1                   1              1
# 202                               1                   1              0
# 203                               1                   1              0
# 204                               1                   1              0
# 205                               1                   1              0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_00_inp, y, test_size=0.30, random_state=67, stratify=y)

# %%
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
df_00_inp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541102 entries, 194 to 624649
# Data columns (total 7 columns):
# AGENT_REPRESENTING_EMPLOYER    541102 non-null int64
# FULL_TIME_POSITION             541102 non-null int64
# H1B_DEPENDENT                  541102 non-null int64
# WILLFUL_VIOLATOR               541102 non-null int64
# SUPPORT_H1B                    541102 non-null int64
# LABOR_CON_AGREE                541102 non-null int64
# rate                           541102 non-null float64
# dtypes: float64(1), int64(6)
# memory usage: 53.0 MB

# %%
pd.crosstab(y_test, rfc.predict(X_test))
# Out:
# col_0       0   1
# row_0
# 0      160046  41
# 1        2190  54

# %%
skm.roc_auc_score(y_test,rfc.predict(X_test))
# Out:
# 0.5119040301916048

# %%
df_2017_status.EMPLOYER_NAME.str.contains('UNIVERSITY', na=False)
# Out:
# 194       False
# 195       False
# 196       False
# 197       False
# 198        True
# 199       False
# 200       False
# 201       False
# 202       False
# 203       False
# 204       False
# 205       False
# 206       False
# 207       False
# 208       False
# 209       False
# 210       False
# 211       False
# 212        True
# 213       False
# 214       False
# 215        True
# 216       False
# 217       False
# 218       False
# 219       False
# 220       False
# 221       False
# 222       False
# 223       False
#           ...
# 624574    False
# 624575    False
# 624576    False
# 624577    False
# 624578    False
# 624579    False
# 624580    False
# 624581    False
# 624582    False
# 624583    False
# 624584     True
# 624585    False
# 624586    False
# 624588     True
# 624589    False
# 624590    False
# 624599    False
# 624601    False
# 624604     True
# 624605    False
# 624606    False
# 624609    False
# 624612    False
# 624613    False
# ...

# %%
df_2017_status.EMPLOYER_NAME.str.contains('UNIVERSITY').sum()
# Out:
# 18109

# %%
df_2017_status[df_2017_status.EMPLOYER_NAME.str.contains('UNIVERSITY', na=False)].CASE_STATUS.mean()
# Out:
# 0.018002098404108453

# %%
df_2017_status[df_2017_status.EMPLOYER_NAME.str.contains('UNIVERSITY', na=False)].groupby('EMPLOYER_NAME')['CASE_STATUS'].mean().nlargest(100)
# Out:
# EMPLOYER_NAME
# EASTERN ILLINOIS UNIVERSITY                                 1.000000
# LINCOLN  UNIVERSITY                                         1.000000
# TRINITY UNIVERSITY                                          0.600000
# BETHEL UNIVERSITY                                           0.500000
# KING UNIVERSITY                                             0.500000
# MCMURRY UNIVERSITY                                          0.500000
# NEW YORK UNIVERSITY ABU DHABI                               0.500000
# ST. THOMAS UNIVERSITY, INC.                                 0.500000
# THE BROOKDALE UNIVERSITY HOSPITAL AND MEDICAL CENTER        0.500000
# UNIVERSITY OF WISCONSIN-PLATTEVILLE                         0.500000
# WEST LIBERTY UNIVERSITY                                     0.500000
# ANGELO STATE UNIVERSITY                                     0.333333
# BRIAR CLIFF UNIVERSITY                                      0.333333
# ...

# %%
df_2017_status[df_2017_status.EMPLOYER_NAME=='TENNESSE STATE UNIVERSITY'].T
# Out:
#                                                                     29138   \
# CASE_NUMBER                                             I-200-16299-651131
# CASE_STATUS                                                              1
# CASE_SUBMITTED                                         2016-10-25 00:00:00
# DECISION_DATE                                                   10/28/2016
# VISA_CLASS                                                            H-1B
# EMPLOYMENT_START_DATE                                           12/01/2016
# EMPLOYMENT_END_DATE                                             12/01/2019
# EMPLOYER_NAME                                    TENNESSE STATE UNIVERSITY
# EMPLOYER_BUSINESS_DBA                                                  NaN
# EMPLOYER_ADDRESS                                 3500 JOHN A. MERRITT BLVD
# EMPLOYER_CITY                                                    NASHVILLE
# ...

# %%
#use average for employer with application < 5
mask = df_2017_status.per_employer < 5
column_name = 'employer_rate='
df_2017_status.loc[mask, column_name] = df_2017_status[(df_2017_status.per_employer < 5)].CASE_STATUS.mean()

# %%
df_2017_status.head(20)
# Out:
#             CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 194  I-200-09209-039181            0     2016-09-27    10/03/2016       H-1B
# 195  I-200-16266-171133            0     2016-09-27    10/03/2016       H-1B
# 196  I-200-16266-208642            0     2016-09-27    10/03/2016       H-1B
# 197  I-200-16263-193057            0     2016-09-27    10/03/2016       H-1B
# 198  I-200-16263-433294            0     2016-09-27    10/03/2016       H-1B
# 199  I-200-16263-134468            0     2016-09-27    10/03/2016       H-1B
# 200  I-200-16095-028210            0     2016-09-27    10/03/2016       H-1B
# 201  I-200-16271-793080            0     2016-09-27    10/03/2016       H-1B
# 202  I-200-16155-597652            0     2016-09-27    10/03/2016       H-1B
# 203  I-200-16189-475335            0     2016-09-27    10/03/2016       H-1B
# 204  I-200-16237-360926            0     2016-09-27    10/03/2016       H-1B
# ...

# %%
df_00_inp['rate']=df_2017_status['employer_rate=']
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_00_inp.head(20)
# Out:
#      AGENT_REPRESENTING_EMPLOYER  FULL_TIME_POSITION  H1B_DEPENDENT  \
# 194                            1                   1              1
# 195                            1                   1              1
# 196                            1                   1              0
# 197                            1                   1              0
# 198                            0                   1              0
# 199                            1                   1              1
# 200                            1                   1              0
# 201                            1                   1              1
# 202                            1                   1              0
# 203                            1                   1              0
# 204                            1                   1              0
# 205                            1                   1              0
# 206                            1                   1              0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df_00_inp, y, test_size=0.30, random_state=67, stratify=y)

# %%
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
skm.roc_auc_score(y_test,rfc.predict(X_test))
# Out:
# 0.5119040301916048

# %%
pd.crosstab(y_test, rfc.predict(X_test))
# Out:
# col_0       0   1
# row_0
# 0      160046  41
# 1        2190  54

# %%
df_2017_status['employer_rate='].describe()
# Out:
# count    541102.000000
# mean          0.013819
# std           0.030812
# min           0.000000
# 25%           0.000000
# 50%           0.002740
# 75%           0.020379
# max           1.000000
# Name: employer_rate=, dtype: float64

# %%
df_2017_status[df_2017_status.AMENDED_PETITION==30].T
# Out:
#                                                49008   \
# CASE_NUMBER                        I-200-16315-809858
# CASE_STATUS                                         0
# CASE_SUBMITTED                    2016-11-14 00:00:00
# DECISION_DATE                              11/18/2016
# VISA_CLASS                                       H-1B
# EMPLOYMENT_START_DATE                      12/05/2016
# EMPLOYMENT_END_DATE                        12/04/2019
# EMPLOYER_NAME                      EPAM SYSTEMS, INC.
# EMPLOYER_BUSINESS_DBA                             NaN
# EMPLOYER_ADDRESS                  41 UNIVERSITY DRIVE
# EMPLOYER_CITY                                 NEWTOWN
# EMPLOYER_STATE                                     PA
# EMPLOYER_POSTAL_CODE                            18940
# EMPLOYER_COUNTRY             UNITED STATES OF AMERICA
# EMPLOYER_PROVINCE                                 NaN
# EMPLOYER_PHONE                             2677599000
# ...

# %%
df_2017_status['per_soc']=df_2017_status.groupby('SOC_NAME')['SOC_NAME'].transform('count')

# %%
df_2017_status['per_soc'].describe()
# Out:
# count    541102.000000
# mean      47580.202165
# std       41600.781273
# min           1.000000
# 25%        5744.000000
# 50%       47559.000000
# 75%       83386.000000
# max      108045.000000
# Name: per_soc, dtype: float64

# %%
#how many deny for SOC
df_2017_status['per_soc_deny']=df_2017_status.groupby('SOC_NAME')['CASE_STATUS'].transform('sum')

# %%
#denial rate for soc
df_2017_status['soc_rate=']=df_2017_status['per_soc_deny']/df_2017_status['per_soc']

# %%
df_2017_status.head()
# Out:
#             CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 194  I-200-09209-039181            0     2016-09-27    10/03/2016       H-1B
# 195  I-200-16266-171133            0     2016-09-27    10/03/2016       H-1B
# 196  I-200-16266-208642            0     2016-09-27    10/03/2016       H-1B
# 197  I-200-16263-193057            0     2016-09-27    10/03/2016       H-1B
# 198  I-200-16263-433294            0     2016-09-27    10/03/2016       H-1B
#
#     EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 194            10/01/2016          09/20/2019
# 195            09/27/2016          09/21/2019
# 196            03/27/2017          03/26/2020
# 197            03/15/2017          03/12/2020
# 198            11/07/2016          08/31/2017
#
#                             EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 194           CLOUDWICK TECHNOLOGIES INC.                   NaN
# 195     TATA CONSULTANCY SERVICES LIMITED                   NaN
# ...

# %%
df_2017_status['soc_rate='].describe()
# Out:
# count    541102.000000
# mean          0.013825
# std           0.019132
# min           0.000000
# 25%           0.008715
# 50%           0.010560
# 75%           0.015306
# max           1.000000
# Name: soc_rate=, dtype: float64

# %%
#use average for employer with application < 5
mask = df_2017_status.per_soc < 5
column_name = 'soc_rate='
df_2017_status.loc[mask, column_name] = df_2017_status[(df_2017_status.per_soc < 5)].CASE_STATUS.mean()

# %%
df_2017_status[(df_2017_status.per_soc < 5)].CASE_STATUS.mean()
# Out:
# 0.14686468646864687

# %%
df_2017_status[(df_2017_status.per_soc < 5)].CASE_STATUS.sum()
# Out:
# 89

# %%
df_2017_status[(df_2017_status.per_employer < 5)].CASE_STATUS.sum()
# Out:
# 2947

# %%
df_2017_status[(df_2017_status.per_employer < 5)].CASE_STATUS.mean()
# Out:
# 0.0364556273039907

# %%
df_2017_status.CASE_STATUS.sum()
# Out:
# 7481

# %%
df_00_inp['rate_soc']=df_2017_status['soc_rate=']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_00_inp, y, test_size=0.30, random_state=67, stratify=y)

# %%
X_train.head()
# Out:
#         AGENT_REPRESENTING_EMPLOYER  FULL_TIME_POSITION  H1B_DEPENDENT  \
# 458202                            1                   1              1
# 210107                            1                   1              0
# 19604                             1                   1              1
# 442735                            1                   0              1
# 577271                            1                   1              0
#
#         WILLFUL_VIOLATOR  SUPPORT_H1B  LABOR_CON_AGREE      rate  rate_soc
# 458202                 0            1                1  0.000000  0.009390
# 210107                 0            1                1  0.036456  0.033538
# 19604                  0            1                1  0.002081  0.008715
# 442735                 0            0                1  0.000000  0.009390
# 577271                 0            1                1  0.020379  0.015436

# %%
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
skm.roc_auc_score(y_test,rfc.predict(X_test))
# Out:
# 0.5297793775948945

# %%
pd.crosstab(y_test, rfc.predict(X_test))
# Out:
# col_0       0    1
# row_0
# 0      159848  239
# 1        2107  137

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression().fit(X_train, y_train)

# %%
skm.roc_auc_score(y_test,clf.predict(X_test))
# Out:
# 0.5290494617081374

# %%
pd.crosstab(y_test, clf.predict(X_test))
# Out:
# col_0       0    1
# row_0
# 0      159971  116
# 1        2112  132
