# %%
import model

# %%
    data_path = "H-1B_2017.csv"
    mo = model.Model(data_path)

# %%
    X_train, X_test, y_train, y_test = mo.get_data()
# Out:
# /home/ji/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: DtypeWarning: Columns (14,15,16,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/ji/Downloads/create_features_DF.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['CASE_STATUS'] = (df['CASE_STATUS'] == 'DENIED').astype(int)

# %%
X_train.head()
# Out:
#                CASE_NUMBER  CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 458202  I-200-17123-525093            0     05/03/2017    05/09/2017
# 210107  I-200-17052-122343            0     02/27/2017    03/03/2017
# 19604   I-200-16287-728135            0     10/14/2016    10/20/2016
# 442735  I-200-17110-455846            0     04/20/2017    04/26/2017
# 577271  I-200-17223-470571            0     08/14/2017    08/18/2017
#
#        VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 458202       H-1B            05/15/2017          05/14/2020
# 210107       H-1B            08/24/2017          08/23/2020
# 19604        H-1B            10/14/2016          10/12/2019
# 442735       H-1B            04/27/2017          04/27/2020
# 577271       H-1B            08/18/2017          08/17/2020
#
#                                EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 458202                       INFO LABS, INC.                   NaN
# 210107                           BOCOUP, LLC                   NaN
# 19604      TATA CONSULTANCY SERVICES LIMITED                   NaN
# 442735  CONCEPTS INFORMATION TECHNOLOGY, INC                   NaN
# 577271               DELOITTE CONSULTING LLP                   NaN
#
#                 EMPLOYER_ADDRESS        ...         H1B_DEPENDENT  \
# 458202         690 CENTER STREET        ...                     1
# 210107          201 SOUTH STREET        ...                     0
# 19604   9201 CORPORATE BOULEVARD        ...                     1
# 442735      8230 BOONE BOULEVARD        ...                     1
# 577271        1700 MARKET STREET        ...                     0
#
#        WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE  \
# 458202                0           Y               M
# 210107                0           M               Y
# 19604                 0           Y               M
# 442735                0           N               Y
# 577271                0           M               M
#
#        PUBLIC_DISCLOSURE_LOCATION    WORKSITE_CITY WORKSITE_COUNTY  \
# 458202                        NaN  FOX RIVER GROVE         MCHENRY
# 210107                        NaN           BOSTON         SUFFOLK
# 19604                         NaN       NORTHBROOK            COOK
# 442735                        NaN        FRANKFORT        FRANKLIN
# 577271                        NaN       SACRAMENTO      SACRAMENTO
#
#        WORKSITE_STATE WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 458202             IL                60021                NaN
# 210107             MA                02111                NaN
# 19604              IL                60062                NaN
# 442735             KY                40601                NaN
# 577271             CA                95814                NaN
#
# [5 rows x 52 columns]

# %%
X, df_save_em, df_save_so = model.create_features_df(X_train, predict=False)

# %%
X.head()
# Out:
#         FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  EMPLOYER_RATE  \
# 458202                   1              1                 0       0.000000
# 210107                   1              0                 0       0.034285
# 19604                    1              1                 0       0.002458
# 442735                   0              1                 0       0.000000
# 577271                   1              0                 0       0.021560
#
#         SOC_RATE  STATE_AK  STATE_AL  STATE_AR  STATE_AZ  STATE_CO    ...      \
# 458202  0.009345         0         0         0         0         0    ...
# 210107  0.031153         0         0         0         0         0    ...
# 19604   0.008761         0         0         0         0         0    ...
# 442735  0.009345         0         0         0         0         0    ...
# 577271  0.014541         0         0         0         0         0    ...
#
#         LABOR_Y  LEVEL_Level I  LEVEL_Level II  LEVEL_Level III  \
# 458202        0              1               0                0
# 210107        1              0               0                0
# 19604         0              0               1                0
# 442735        1              1               0                0
# 577271        0              0               0                0
#
#         LEVEL_Level IV  UNIT_Bi-Weekly  UNIT_Hour  UNIT_Month  UNIT_Week  \
# 458202               0               0          0           0          0
# 210107               1               0          0           0          0
# 19604                0               0          0           0          0
# 442735               0               0          1           0          0
# 577271               0               0          0           0          0
#
#         UNIT_Year
# 458202          1
# 210107          1
# 19604           1
# 442735          0
# 577271          1
#
# [5 rows x 77 columns]

# %%
X_test.head()
# Out:
#         FULL_TIME_POSITION  H1B_DEPENDENT  WILLFUL_VIOLATOR  EMPLOYER_RATE  \
# 222268                   1              0                 0       0.034285
# 422385                   1              0                 0       0.017442
# 564464                   1              1                 0       0.002458
# 6090                     1              0                 0       0.000000
# 403535                   1              1                 0       0.025090
#
#         SOC_RATE  STATE_AK  STATE_AL  STATE_AR  STATE_AZ  STATE_CO    ...      \
# 222268  0.021592         0         0         0         0         0    ...
# 422385  0.013827         0         0         0         0         0    ...
# 564464  0.009920         0         0         0         0         0    ...
# 6090    0.020307         0         0         0         0         0    ...
# 403535  0.015510         0         0         0         0         0    ...
#
#         LABOR_Y  LEVEL_Level I  LEVEL_Level II  LEVEL_Level III  \
# 222268        1              0               0                1
# 422385        0              0               1                0
# 564464        0              0               0                0
# 6090          0              0               1                0
# 403535        0              0               0                0
#
#         LEVEL_Level IV  UNIT_Bi-Weekly  UNIT_Hour  UNIT_Month  UNIT_Week  \
# 222268               0               0          0           0          0
# 422385               0               0          0           0          0
# 564464               0               0          0           0          0
# 6090                 0               0          0           0          0
# 403535               0               0          0           0          0
#
#         UNIT_Year
# 222268          1
# 422385          1
# 564464          1
# 6090            1
# 403535          1
#
# [5 rows x 77 columns]

# %%
    X_test=model.create_features_df(X_test)
    group=dict(zip(df_save_em.EMPLOYER_NAME,df_save_em.EMPLOYER_RATE))
    X_test['EMPLOYER_RATE'] = X_test['EMPLOYER_NAME'].map(group, na_action=None)
    X_test.fillna(y_train.mean(), inplace=True)

# %%
    group=dict(zip(df_save_so.SOC_NAME,df_save_so.SOC_RATE))
    X_test['SOC_RATE'] = X_test['SOC_NAME'].map(group, na_action=None)
    X_test.fillna(y_train.mean(), inplace=True)

# %%
    missing_cols = set(X.columns)-set(X_test.columns)
# Add a missing column in test set with default value equal to 0
    for c in missing_cols:
        X_test[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
    X_test= X_test[X.columns]
    X_test.drop(['EMPLOYER_NAME','SOC_NAME','CASE_STATUS'], inplace=True, axis=1)
    X.drop(['EMPLOYER_NAME','SOC_NAME', 'CASE_STATUS'], inplace=True, axis=1)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbcc=GradientBoostingClassifier(n_estimators=500, max_depth=8, subsample=0.5,max_features='auto', learning_rate=0.05)

# %%
gbcc.fit(X, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.05, loss='deviance', max_depth=8,
#               max_features='auto', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=500,
#               presort='auto', random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)

# %%
import sklearn.metrics as skm
skm.roc_auc_score(y_test,gbcc.predict_proba(X_test)[:, 1])
# Out:
# 0.7281987041092752

# %%
v_probs =gbcc.predict_proba(X_test)[:, 1]

# %%
model.plot_roc(v_probs, y_test, "ROC plot of H1-B prediction", "False Positive Rate (1 - Specificity)", "True Positive Rate (Sensitivity, Recall)")
# Out:
# /home/ji/Downloads/create_features_DF.py:199: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# /home/ji/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# /home/ji/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)

# %%
    mo.fit(X, y_train)
    
    print('roc_auc_score:')
# Out:
# roc_auc_score:

# %%
#import again?
import sklearn.metrics as skm
import pandas as pd
print(skm.roc_auc_score(y_test,mo.predict_proba(X_test)))
print()
pd.crosstab(y_test, mo.predict(X_test))
# Out:
# 0.7149048686839812
# col_0       0    1
# row_0
# 0      159576  511
# 1        2090  154

# %%
v_probs = mo.predict_proba(X_test)

# %%
v_probs
# Out:
# array([0.00064982, 0.        , 0.        , ..., 0.        , 0.0062    ,
#        0.        ])

# %%
#change roc plot code?
model.plot_roc(v_probs, y_test, "ROC plot of H1-B prediction", "False Positive Rate (1 - Specificity)", "True Positive Rate (Sensitivity, Recall)")
# Out:
# /home/ji/Downloads/create_features_DF.py:199: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# /home/ji/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# /home/ji/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
